# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=os.environ["HF_TOKEN"],
)

completion = client.chat.completions.create(
    model="moonshotai/Kimi-K2-Instruct-0905",
    messages=[
        {
            "role": "user",
            "content": "Create a recipe for a chocolate cake."
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 6
#       1 import os
#       2 from openai import OpenAI
#       4 client = OpenAI(
#       5     base_url="https://router.huggingface.co/v1",
# ----> 6     api_key=os.environ["HF_TOKEN"],
#       7 )
#       9 completion = client.chat.completions.create(
#      10     model="moonshotai/Kimi-K2-Instruct-0905",
#      11     messages=[
#    (...)     16     ],
#      17 )
#      19 print(completion.choices[0].message)
#
# File ~\anaconda3-new\envs\newChatbot\Lib\os.py:714, in _Environ.__getitem__(self, key)
#     711     value = self._data[self.encodekey(key)]
#     712 except KeyError:
#     713     # raise KeyError with the original key value
# --> 714     raise KeyError(key) from None
#     715 return self.decodevalue(value)
#
# KeyError: 'HF_TOKEN'

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="together",
    api_key=os.environ["HF_TOKEN"],
)

# output is a PIL.Image object
image = client.text_to_image(
    "A fantasy forest with glowing mushrooms",
    model="black-forest-labs/FLUX.1-dev",
)
